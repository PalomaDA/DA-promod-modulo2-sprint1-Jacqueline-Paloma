# %% [markdown]
# Ejercicio 1º Ayer creamos un par de gráficas para los tickets de la categoría "Software" y "Hardware", donde visualizamos el número de clientes que teníamos en cada grupo de satisfacción. Hoy tendréis que hacer dos gráficas con subplots:
# En la primera debéis mostrar la cantidad de tickets en función del tipo (si es Problema o Solicitud), cada subplot corresponderá a cada una de las categorías. Debéis:
# -Poner nombre a los ejes de cada uno de los subplots
# -Poner un títulos a cada uno de los subplots
# -Poner el color de las líneas en negro.
# -Establecer el tamaño de la gráfica a 15 x 5
# -Ponerle marcadores a las gráficas
# -No incluir leyenda

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df_ep = pd.read_csv("datos/empleados_puestos (1).csv")
df_ep.sample(3)
# Out:
#       Unnamed: 0 Turno  ID Empleado  Apellido  Nombre ID Puesto  \
# 440          440   NaN         1141      Soto    Ruth  90-14000
# 1931        1931   NaN         1891    RIVERA  ADOLFO  35-34000
# 1293        1293   NaN         1310  Valencia    Ruth  30-13100
#
#                             Email  \
# 440       ruth.soto@tractchun.com
# 1931  adolfo.rivera@tractchun.com
# 1293  ruth.valencia@tractchun.com
#
#                                                  Puesto  \
# 440                 Supervisor de Ingeniería de Calidad
# 1931  Coordinador de medio Ambiente, Seguridad e Hig...
# 1293                          Controlador de Documentos
#
#                                      Departamento    Tipo Puesto
# 440                         INGENIERIA DE CALIDAD  Mandos Medios
# 1931                                     PERSONAL  Mandos Medios
# 1293  AUDITORIA INTERNA, CALIBRACION Y METROLOGIA  Mandos Medios

# %%
df_ht= pd.read_csv("datos/historico_tickets (1).csv")
df_ht.sample(3)
# Out:
#        Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 7008         7075  KMLTSR-8042424900  2016-02-24         1040         39
# 29451        1597  GDLTST-5543341480  2018-08-29         1348         34
# 30619        2765  GHLTNR-5043201802  2018-04-11          350          8
#
#            categoría       tipo   severidad        prioridad  días_resolución  \
# 7008         Sistema  Solicitud  2 - Normal        2 - Media                4
# 29451        Sistema  Solicitud  2 - Normal  0 - Sin Asignar                5
# 30619  Acceso-&Login  Solicitud  2 - Normal         3 - Alta                0
#
#        satisfacción     semestre   año
# 7008              5   1 semestre  2016
# 29451             5  2º semestre  2018
# 30619             5   1 semestre  2018

# %%
sp = df_ht["tipo"].value_counts()
sp
# Out:
# Solicitud    73138
# Problema     24248
# Name: tipo, dtype: int64

# %%
sp1=df_ht["categoría"].value_counts()
sp1
# Out:
# Sistema          38961
# Software         19543
# Hardware          9717
# Acceso/Login      8659
# Acceso99Login     6426
# Acceso-&Login     5672
# Acceso%&Login     4526
# Acceso&%Login     3882
# Name: categoría, dtype: int64

# %%
df_Software = df_ht[df_ht["categoría"]== "Software"].reset_index()
df_Software.sample(3)
# Out:
#        index  Unnamed: 0          id_ticket       fecha  id_empleado  \
# 14203  70872        2574  GDRTER-5744014550  2020-07-02         1255
# 15334  76194        7896  GWLTER-7143840852  2020-01-10         1435
# 10477  52525        5717  GWLTER-4643657841  2019-07-11         1054
#
#        id_agente categoría       tipo   severidad        prioridad  \
# 14203         45  Software  Solicitud   1 - Menor  0 - Sin Asignar
# 15334         28  Software  Solicitud  2 - Normal         1 - Baja
# 10477         18  Software  Solicitud  2 - Normal         1 - Baja
#
#        días_resolución  satisfacción     semestre   año
# 14203                7             5  2º semestre  2020
# 15334               11             1   1 semestre  2020
# 10477                6             5  2º semestre  2019

# %%
sof_tipo = df_Software["tipo"].value_counts().reset_index()
sof_tipo
# Out:
#        index   tipo
# 0  Solicitud  14618
# 1   Problema   4925

# %%
df_Hardware = df_ht[df_ht["categoría"]== "Hardware"].reset_index()
df_Hardware.sample(3)
# Out:
#       index  Unnamed: 0          id_ticket       fecha  id_empleado  \
# 515    5045        5099  KHLEER-9542419610  2016-02-19          211
# 1748  17618        4679  KDLTER-0742872350  2017-05-17         1555
# 7246  72034        3736  GHLTER-7144075778  2020-09-01         1237
#
#       id_agente categoría       tipo   severidad        prioridad  \
# 515          16  Hardware   Problema  2 - Normal         3 - Alta
# 1748         13  Hardware  Solicitud  2 - Normal  0 - Sin Asignar
# 7246         37  Hardware  Solicitud  2 - Normal         3 - Alta
#
#       días_resolución  satisfacción     semestre   año
# 515                 5             3   1 semestre  2016
# 1748               15             4   1 semestre  2017
# 7246                1             5  2º semestre  2020

# %%
hd_tipo = df_Hardware["tipo"].value_counts().reset_index()
hd_tipo
# Out:
#        index  tipo
# 0  Solicitud  7356
# 1   Problema  2361

# %%
fig, ax = plt.subplots(1,2, figsize = (15,5))
ax[0].bar(hd_tipo["index"],hd_tipo["tipo"], color ="blue", edgecolor = "black")
ax[1].bar(sof_tipo["index"],sof_tipo["tipo"], color = "green", edgecolor = "black")
ax[0].set_title("Gráfico Hardware")
ax[1]. set_title("Grafico Software")
ax[0].set_xlabel("tipos de incidencia")
ax[1].set_ylabel("números")
ax[0].set_ylabel("números") 
ax[1].set_xlabel("tipos de incidencia")
plt.show()

# %% [markdown]
# En la segunda debéis mostrar el número de tickets en función de la satisfacción.
# -De nuevo tendréis que ponerle nombre a los ejes y título a cada gráfica
# -En este caso el subplot deberá tener dos filas y una columna
# -No incluir leyenda
# -Cambiar el color de las barras

# %%
hd_satisfacción = df_Hardware["satisfacción"].value_counts().reset_index()
hd_satisfacción
# Out:
#    index  satisfacción
# 0      5          5101
# 1      4          2687
# 2      1          1000
# 3      3           744
# 4      2           185

# %%
sof_satisfacción = df_Software["satisfacción"].value_counts().reset_index()
sof_satisfacción
# Out:
#    index  satisfacción
# 0      5         10236
# 1      4          5485
# 2      1          1969
# 3      3          1465
# 4      2           388

# %%
fig, ax = plt.subplots(1,2, figsize = (15,5))
ax[0].bar(hd_satisfacción["index"],hd_satisfacción["satisfacción"], color ="blue", edgecolor = "black")
ax[1].bar(sof_satisfacción["index"],sof_satisfacción["satisfacción"], color = "green", edgecolor = "black")
ax[0].set_title("Satisfacción Hardware")
ax[1]. set_title("Satisfacción Software")
ax[0].set_xlabel("satisfacción")
ax[1].set_ylabel("números ticket")
ax[0].set_ylabel("números ticket") 
ax[1].set_xlabel("satisfacción")
plt.show()

# %% [markdown]
# Ejercicio 2º Cread un subplot con dos gráficas, dónde en la primera tengamos el número de empleados por departamento y en la otra por tipo de puesto. Debéis:
# Poner leyenda a la gráfica
# Cada línea debe ir en un color
# Ponerle nombre a los ejes y a la gráfica.
# Poner marcadores a las lineas.

# %%
df_ep = pd.read_csv("datos/empleados_puestos (1).csv")
df_ep.sample(3)
# Out:
#       Unnamed: 0 Turno  ID Empleado  Apellido  Nombre ID Puesto  \
# 1340        1340   NaN          181    Hoyos    Juan   15-22211
# 1351        1351   NaN         1387  SIMANCAS  CANETT  50-33100
# 129          129   NaN         1348    DANIEL   MARCO  15-24100
#
#                               Email                               Puesto  \
# 1340     juan .hoyos @tractchun.com                             Mecánico
# 1351  canett.simancas@tractchun.com  Supervisor de Control de Producción
# 129      marco.daniel@tractchun.com             Supervisor de Producción
#
#                Departamento    Tipo Puesto
# 1340             PRODUCCION      Operativo
# 1351  CONTROL DE PRODUCCION  Mandos Medios
# 129              PRODUCCION  Mandos Medios

# %%
df_empleados= df_ep["Departamento"].value_counts().reset_index()

df_empleados
# Out:
#                                           index  Departamento
# 0                                    PRODUCCION           475
# 1                         INGENIERIA DE CALIDAD           395
# 2                                 MANTENIMIENTO           258
# 3                     INGENIERIA DE MANUFACTURA           228
# 4                   SISTEMAS, TRAFICO Y ADUANAS           160
# 5                         CONTROL DE PRODUCCION           127
# 6                                    MATERIALES           125
# 7                              Recursos Humanos           117
# 8   AUDITORIA INTERNA, CALIBRACION Y METROLOGIA            70
# 9                                  CONTABILIDAD            25
# 10                                     PERSONAL            20

# %%
df_puesto= df_ep["Tipo Puesto"].value_counts().reset_index()

df_puesto
# Out:
#             index  Tipo Puesto
# 0   Mandos Medios         1060
# 1       Operativo          577
# 2  Administrativo          321
# 3        Gerencia           42

# %%
fig, ax = plt.subplots(1,2, figsize = (30,10))
ax[0].plot(df_empleados["index"],df_empleados["Departamento"],color="green", marker = ".", linewidth=0.5,label ="empleados")
ax[1].plot(df_puesto["index"],df_puesto["Tipo Puesto"],color="pink", marker = "8", linewidth=0.5, label = "nª puesto")
ax[0].set_xticklabels(df_empleados["index"],rotation="vertical")
ax[0].set_title("Empleados departamento")
ax[1]. set_title("Puesto empleados")

ax[0].set_xlabel("puestos")
ax[1].set_ylabel("números empleados")

ax[0].set_ylabel("números empleados") 
ax[1].set_xlabel("tipo puesto")

ax[0].legend(loc="upper right")
ax[1].legend(loc="upper right")
plt.show()
# Out:
# /tmp/ipykernel_3595/1157840137.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(df_empleados["index"],rotation="vertical")

# %% [markdown]
# Ejercicio 3º Guardad las figuras creadas en cada caso. Podéis usar el formato que queráis. Guarda todas las fotos en una carpeta llamada Visualizacion-II.
