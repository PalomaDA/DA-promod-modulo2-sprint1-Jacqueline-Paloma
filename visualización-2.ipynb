# %% [markdown]
# Ejercicio 1º Ayer creamos un par de gráficas para los tickets de la categoría "Software" y "Hardware", donde visualizamos el número de clientes que teníamos en cada grupo de satisfacción. Hoy tendréis que hacer dos gráficas con subplots:
# En la primera debéis mostrar la cantidad de tickets en función del tipo (si es Problema o Solicitud), cada subplot corresponderá a cada una de las categorías. Debéis:
# -Poner nombre a los ejes de cada uno de los subplots
# -Poner un títulos a cada uno de los subplots
# -Poner el color de las líneas en negro.
# -Establecer el tamaño de la gráfica a 15 x 5
# -Ponerle marcadores a las gráficas
# -No incluir leyenda

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df_ep = pd.read_csv("datos/empleados_puestos (1).csv")
df_ep.sample(3)
# Out:
#       Unnamed: 0 Turno  ID Empleado  Apellido   Nombre ID Puesto  \
# 18            18   NaN          336    Zapata   Solina  15-24100
# 808          808   NaN         1530    Lennis   Yasmir  10-32110
# 1823        1823   NaN         1604  FIGUEROA  IGNACIO  20-31210
#
#                                Email                    Puesto  \
# 18       solina.zapata@tractchun.com  Supervisor de Producción
# 808      yasmir.lennis@tractchun.com               Almacenista
# 1823  ignacio.figueroa@tractchun.com                Capturista
#
#                      Departamento     Tipo Puesto
# 18                     PRODUCCION   Mandos Medios
# 808                    MATERIALES  Administrativo
# 1823  SISTEMAS, TRAFICO Y ADUANAS  Administrativo

# %%
df_ht= pd.read_csv("datos/historico_tickets (1).csv")
df_ht.sample(3)
# Out:
#        Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 25023       12084  TDLENR-5142877228  2017-05-22         1602         22
# 59655       12847  SDLTER-7543616471  2019-05-31          187         14
# 31148        3294  GHLTSR-6043216260  2018-04-26          546         42
#
#            categoría       tipo   severidad        prioridad  días_resolución  \
# 25023  Acceso%&Login   Problema  2 - Normal  0 - Sin Asignar                1
# 59655       Software  Solicitud  2 - Normal  0 - Sin Asignar                5
# 31148        Sistema  Solicitud  2 - Normal         3 - Alta               10
#
#        satisfacción    semestre   año
# 25023             4  1 semestre  2017
# 59655             5  1 semestre  2019
# 31148             5  1 semestre  2018

# %%
sp = df_ht["tipo"].value_counts()
sp
# Out:
# Solicitud    73138
# Problema     24248
# Name: tipo, dtype: int64

# %%
df_solicitud = df_ht[df_ht["tipo"]== "Solicitud"]
df_problema = df_ht[df_ht["tipo"]== "Problema"]
df_solicitud.sample(3)
# Out:
#        Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 11197       11292  TDRTSR-6642392627  2016-01-23          252         36
# 35098        7244  KDRTET-1843395570  2018-10-22         1617         25
# 19217        6278  KHLTER-8242945587  2017-07-29          928         15
#
#       categoría       tipo   severidad        prioridad  días_resolución  \
# 11197   Sistema  Solicitud   1 - Menor  0 - Sin Asignar                6
# 35098  Hardware  Solicitud   3 - Mayor  0 - Sin Asignar               12
# 19217  Software  Solicitud  2 - Normal         3 - Alta                0
#
#        satisfacción     semestre   año
# 11197             4   1 semestre  2016
# 35098             5  2º semestre  2018
# 19217             1  2º semestre  2017

# %%
df_problema.sample(3)
# Out:
#        Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 90438       22140  SWLESR-0343944610  2020-04-23         1721         16
# 91606       23308  TDLENR-5343929291  2020-04-08         1689         22
# 74382        6084  GMLENR-8043851767  2020-01-21         1946         47
#
#           categoría      tipo    severidad        prioridad  días_resolución  \
# 90438       Sistema  Problema  4 - Crítico         1 - Baja                3
# 91606  Acceso/Login  Problema   2 - Normal  0 - Sin Asignar                3
# 74382  Acceso/Login  Problema   2 - Normal        2 - Media                0
#
#        satisfacción    semestre   año
# 90438             4  1 semestre  2020
# 91606             5  1 semestre  2020
# 74382             5  1 semestre  2020

# %%
fig, ax = plt.subplots(1,2, figsize = (15,5))
ax[0].h(df_solicitud["tipo"] ,df_solicitud["id_ticket"] )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_16490/1735004721.py in <module>
#       1 fig, ax = plt.subplots(1,2, figsize = (15,5))
# ----> 2 ax[0].h(df_solicitud["tipo"] ,df_solicitud["id_ticket"] )
#       3 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'h'

# %% [markdown]
# En la segunda debéis mostrar el número de tickets en función de la satisfacción.
# -De nuevo tendréis que ponerle nombre a los ejes y título a cada gráfica
# -En este caso el subplot deberá tener dos filas y una columna
# -No incluir leyenda
# -Cambiar el color de las barras

# %%
df_ht.head(5)
# Out:
#    Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 0           0  GDDENR-5042564453  2016-07-13         1735          4
# 1           1  GDDENR-8042508060  2016-05-18         1566         10
# 2           2  GDDESR-1342539995  2016-06-18          569         29
# 3           3  GDDTSR-5942488006  2016-04-28          320         40
# 4           4  GDLEER-0042524120  2016-06-03         1842         31
#
#        categoría       tipo           severidad        prioridad  \
# 0  Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 1  Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 2        Sistema   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 3        Sistema  Solicitud  0 - Sin Clasificar  0 - Sin Asignar
# 4       Software   Problema          2 - Normal  0 - Sin Asignar
#
#    días_resolución  satisfacción     semestre   año
# 0                0             5  2º semestre  2016
# 1                0             5   1 semestre  2016
# 2                3             5   1 semestre  2016
# 3                9             5   1 semestre  2016
# 4                0             5   1 semestre  2016

# %%
plt.figure()
plt.bar(df_ht["satisfacción"],df_ht["id_ticket"].count())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_16490/2766556908.py in <module>
#       1 plt.figure()
# ----> 2 plt.bar(df_ht["satisfacción"],df_ht["id_ticket"].count())
#       3 plt.show()
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2649         x, height, width=0.8, bottom=None, *, align='center',
#    2650         data=None, **kwargs):
# -> 2651     return gca().bar(
#    2652         x, height, width=width, bottom=bottom, align=align,
#    2653         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2369             elif orientation == 'horizontal':
#    2370                 r.sticky_edges.x.append(l)
# -> 2371             self.add_patch(r)
#    2372             patches.append(r)
#    2373
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in add_patch(self, p)
#    2168         if p.get_clip_path() is None:
#    2169             p.set_clip_path(self.patch)
# -> 2170         self._update_patch_limits(p)
#    2171         self.patches.append(p)
#    2172         p._remove_method = self.patches.remove
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _update_patch_limits(self, patch)
#    2190             p.codes, (mpath.Path.CLOSEPOLY, mpath.Path.STOP), invert=True)]
#    2191         if vertices.size > 0:
# -> 2192             xys = patch.get_patch_transform().transform(vertices)
#    2193             if patch.get_data_transform() != self.transData:
#    2194                 patch_to_data = (patch.get_data_transform() -
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/patches.py in get_patch_transform(self)
#     777         bbox = self.get_bbox()
#     778         return (transforms.BboxTransformTo(bbox)
# --> 779                 + transforms.Affine2D().rotate_deg_around(
#     780                     bbox.x0, bbox.y0, self.angle))
#     781
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/transforms.py in __init__(self, matrix, **kwargs)
#    1878         if matrix is None:
#    1879             # A bit faster than np.identity(3).
# -> 1880             matrix = IdentityTransform._mtx.copy()
#    1881         self._mtx = matrix.copy()
#    1882         self._invalid = 0
#
# KeyboardInterrupt:

# %% [markdown]
# Ejercicio 2º Cread un subplot con dos gráficas, dónde en la primera tengamos el número de empleados por departamento y en la otra por tipo de puesto. Debéis:
# Poner leyenda a la gráfica
# Cada línea debe ir en un color
# Ponerle nombre a los ejes y a la gráfica.
# Poner marcadores a las lineas.

# %%
plt.figure()
plt.bar()

# %% [markdown]
# Ejercicio 3º Guardad las figuras creadas en cada caso. Podéis usar el formato que queráis. Guarda todas las fotos en una carpeta llamada Visualizacion-II.
