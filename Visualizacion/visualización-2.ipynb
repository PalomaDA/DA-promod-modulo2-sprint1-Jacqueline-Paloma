# %% [markdown]
# Ejercicio 1º Ayer creamos un par de gráficas para los tickets de la categoría "Software" y "Hardware", donde visualizamos el número de clientes que teníamos en cada grupo de satisfacción. Hoy tendréis que hacer dos gráficas con subplots:
# En la primera debéis mostrar la cantidad de tickets en función del tipo (si es Problema o Solicitud), cada subplot corresponderá a cada una de las categorías. Debéis:
# -Poner nombre a los ejes de cada uno de los subplots
# -Poner un títulos a cada uno de los subplots
# -Poner el color de las líneas en negro.
# -Establecer el tamaño de la gráfica a 15 x 5
# -Ponerle marcadores a las gráficas
# -No incluir leyenda

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df_ep = pd.read_csv("../datos/empleados_puestos (1).csv")
df_ep.sample(3)
# Out:
#       Unnamed: 0 Turno  ID Empleado  Apellido    Nombre ID Puesto  \
# 212          212   NaN         1564  GUERRERO   ALBERTO  15-24100
# 1399        1399   NaN          571  Cárdenas     Juan   15-24111
# 1834        1834   NaN         1307  GRIJALVA  ARELLANO  40-43210
#
#                                 Email                    Puesto  Departamento  \
# 212    alberto.guerrero@tractchun.com  Supervisor de Producción    PRODUCCION
# 1399     juan .cárdenas@tractchun.com    Operador de Producción    PRODUCCION
# 1834  arellano.grijalva@tractchun.com         Auxiliar Contable  CONTABILIDAD
#
#          Tipo Puesto
# 212    Mandos Medios
# 1399       Operativo
# 1834  Administrativo

# %%
df_ht= pd.read_csv("../datos/historico_tickets (1).csv")
df_ht.sample(3)
# Out:
#        Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 28404         550  GDLTER-5943332995  2018-08-20          199          9
# 29047        1193  GDLTSR-1643216429  2018-04-26         1372          4
# 35366        7512  KHLENR-8043194078  2018-04-04          557         20
#
#            categoría       tipo   severidad        prioridad  días_resolución  \
# 28404       Hardware  Solicitud  2 - Normal  0 - Sin Asignar                4
# 29047        Sistema  Solicitud  2 - Normal  0 - Sin Asignar               16
# 35366  Acceso-&Login   Problema  2 - Normal         3 - Alta                0
#
#        satisfacción     semestre   año
# 28404             5  2º semestre  2018
# 29047             5   1 semestre  2018
# 35366             5   1 semestre  2018

# %%
sp = df_ht["tipo"].value_counts()
sp
# Out:
# Solicitud    73138
# Problema     24248
# Name: tipo, dtype: int64

# %%
sp1=df_ht["categoría"].value_counts()
sp1
# Out:
# Sistema          38961
# Software         19543
# Hardware          9717
# Acceso/Login      8659
# Acceso99Login     6426
# Acceso-&Login     5672
# Acceso%&Login     4526
# Acceso&%Login     3882
# Name: categoría, dtype: int64

# %%
df_Software = df_ht[df_ht["categoría"]== "Software"].reset_index()
df_Software.sample(3)
# Out:
#       index  Unnamed: 0          id_ticket       fecha  id_empleado  \
# 6253  30439        2585  GHLTET-7343315121  2018-08-03         1212
# 107     344         348  GDLTER-5542522717  2016-06-01         1701
# 412    1577        1589  GHLTER-8542529232  2016-06-08         1213
#
#       id_agente categoría       tipo   severidad        prioridad  \
# 6253         21  Software  Solicitud  2 - Normal         3 - Alta
# 107          37  Software  Solicitud  2 - Normal  0 - Sin Asignar
# 412          42  Software  Solicitud  2 - Normal         3 - Alta
#
#       días_resolución  satisfacción     semestre   año
# 6253                3             5  2º semestre  2018
# 107                 5             5   1 semestre  2016
# 412                 5             5   1 semestre  2016

# %%
sof_tipo = df_Software["tipo"].value_counts().reset_index()
sof_tipo
# Out:
#        index   tipo
# 0  Solicitud  14618
# 1   Problema   4925

# %%
df_Hardware = df_ht[df_ht["categoría"]== "Hardware"].reset_index()
df_Hardware.sample(3)
# Out:
#       index  Unnamed: 0          id_ticket       fecha  id_empleado  \
# 3417  34085        6231  KDLTER-7243290868  2018-07-09         1706
# 7845  77856        9558  KDLTER-5544082749  2020-09-08          244
# 6329  63321       16513  SWLTER-8343747762  2019-10-09         1016
#
#       id_agente categoría       tipo   severidad        prioridad  \
# 3417          8  Hardware  Solicitud  2 - Normal  0 - Sin Asignar
# 7845         17  Hardware  Solicitud  2 - Normal  0 - Sin Asignar
# 6329          7  Hardware  Solicitud  2 - Normal         1 - Baja
#
#       días_resolución  satisfacción     semestre   año
# 3417               12             5  2º semestre  2018
# 7845               15             2  2º semestre  2020
# 6329               14             1  2º semestre  2019

# %%
hd_tipo = df_Hardware["tipo"].value_counts().reset_index()
hd_tipo
# Out:
#        index  tipo
# 0  Solicitud  7356
# 1   Problema  2361

# %%
fig, ax = plt.subplots(1,2, figsize = (15,5))
ax[0].bar(hd_tipo["index"],hd_tipo["tipo"], color ="blue", edgecolor = "black")
ax[1].bar(sof_tipo["index"],sof_tipo["tipo"], color = "green", edgecolor = "black")
ax[0].set_title("Gráfico Hardware")
ax[1]. set_title("Grafico Software")
ax[0].set_xlabel("tipos de incidencia")
ax[1].set_ylabel("números")
ax[0].set_ylabel("números") 
ax[1].set_xlabel("tipos de incidencia")

plt.savefig('visualizacion-II/soft_hard.png')
plt.show()

# %% [markdown]
# En la segunda debéis mostrar el número de tickets en función de la satisfacción.
# -De nuevo tendréis que ponerle nombre a los ejes y título a cada gráfica
# -En este caso el subplot deberá tener dos filas y una columna
# -No incluir leyenda
# -Cambiar el color de las barras

# %%
hd_satisfacción = df_Hardware["satisfacción"].value_counts().reset_index()
hd_satisfacción
# Out:
#    index  satisfacción
# 0      5          5101
# 1      4          2687
# 2      1          1000
# 3      3           744
# 4      2           185

# %%
sof_satisfacción = df_Software["satisfacción"].value_counts().reset_index()
sof_satisfacción
# Out:
#    index  satisfacción
# 0      5         10236
# 1      4          5485
# 2      1          1969
# 3      3          1465
# 4      2           388

# %%
fig, ax = plt.subplots(1,2, figsize = (15,5))
ax[0].bar(hd_satisfacción["index"],hd_satisfacción["satisfacción"], color ="blue", edgecolor = "black")
ax[1].bar(sof_satisfacción["index"],sof_satisfacción["satisfacción"], color = "green", edgecolor = "black")
ax[0].set_title("Satisfacción Hardware")
ax[1]. set_title("Satisfacción Software")
ax[0].set_xlabel("satisfacción")
ax[1].set_ylabel("números ticket")
ax[0].set_ylabel("números ticket") 
ax[1].set_xlabel("satisfacción")

plt.savefig('visualizacion-II/satis_soft_hard.png')
plt.show()

# %% [markdown]
# Ejercicio 2º Cread un subplot con dos gráficas, dónde en la primera tengamos el número de empleados por departamento y en la otra por tipo de puesto. Debéis:
# Poner leyenda a la gráfica
# Cada línea debe ir en un color
# Ponerle nombre a los ejes y a la gráfica.
# Poner marcadores a las lineas.

# %%
df_ep = pd.read_csv("../datos/empleados_puestos (1).csv")
df_ep.sample(3)
# Out:
#       Unnamed: 0 Turno  ID Empleado  Apellido     Nombre ID Puesto  \
# 315          315   NaN         1481      COTA     JAVIER  15-24100
# 1533        1533   NaN         1806  FIGUEROA  FRANCISCO  90-14100
# 1654        1654   NaN          720    TANORI      JESUS  30-16000
#
#                                  Email                       Puesto  \
# 315          javier.cota@tractchun.com     Supervisor de Producción
# 1533  francisco.figueroa@tractchun.com         Ingeniero de Calidad
# 1654        jesus.tanori@tractchun.com  Supervisor General de Areas
#
#                                      Departamento    Tipo Puesto
# 315                                    PRODUCCION  Mandos Medios
# 1533                        INGENIERIA DE CALIDAD      Operativo
# 1654  AUDITORIA INTERNA, CALIBRACION Y METROLOGIA  Mandos Medios

# %%
fig,ax = plt.subplots(1,2, figsize = (20,8))

ax[0].hist(x = df_ep['Tipo Puesto'], color = 'green', edgecolor = 'black', bins = 4)
ax[1].hist(x = df_ep['Departamento'], edgecolor = 'black')

ax[0].set_xticklabels(df_ep['Puesto'], rotation=45)
ax[1].set_xticklabels(df_ep['Departamento'], rotation=45)

ax[0].set_title('Tipo de Puesto')
ax[1].set_title('Departamento')

plt.savefig('visualizacion-II/puesto_departamento.png')

plt.show()
# Out:
# /tmp/ipykernel_1132/2253460966.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(df_ep['Puesto'], rotation=45)
# /tmp/ipykernel_1132/2253460966.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_xticklabels(df_ep['Departamento'], rotation=45)

# %%
df_empleados= df_ep["Departamento"].value_counts().reset_index()

df_empleados
# Out:
#                                           index  Departamento
# 0                                    PRODUCCION           475
# 1                         INGENIERIA DE CALIDAD           395
# 2                                 MANTENIMIENTO           258
# 3                     INGENIERIA DE MANUFACTURA           228
# 4                   SISTEMAS, TRAFICO Y ADUANAS           160
# 5                         CONTROL DE PRODUCCION           127
# 6                                    MATERIALES           125
# 7                              Recursos Humanos           117
# 8   AUDITORIA INTERNA, CALIBRACION Y METROLOGIA            70
# 9                                  CONTABILIDAD            25
# 10                                     PERSONAL            20

# %%
df_puesto= df_ep["Tipo Puesto"].value_counts().reset_index()

df_puesto
# Out:
#             index  Tipo Puesto
# 0   Mandos Medios         1060
# 1       Operativo          577
# 2  Administrativo          321
# 3        Gerencia           42

# %% [markdown]
# Ejercicio 3º Guardad las figuras creadas en cada caso. Podéis usar el formato que queráis. Guarda todas las fotos en una carpeta llamada Visualizacion-II.

# %% [markdown]
# - Se hace junto a la figura
